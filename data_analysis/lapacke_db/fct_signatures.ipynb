# %% [markdown]
# #### Building arg Database

# %%
import pandas as pd

real = [
    'bdsdc', 'bdsqr', 'disna', 'gbbrd', 'gbcon', 'gbequ', 'gbequb', 'gbrfs',
    'gbrfsx', 'gbsv', 'gbsvx', 'gbsvxx', 'gbtrf', 'gbtrs', 'gebak', 'gebal',
    'gebrd', 'gecon', 'geequ', 'geequb', 'gees', 'geesx', 'geev', 'geevx',
    'gehrd', 'gejsv', 'gelqf', 'gels', 'gelsd', 'gelss', 'gelsy', 'geqlf',
    'geqp3', 'geqpf', 'geqrf', 'geqrfp', 'gerfs', 'gerfsx', 'gerqf', 'gesdd',
    'gesv', 'gesvd', 'gesvj', 'gesvx', 'gesvxx', 'getrf', 'getri', 'getrs',
    'ggbak', 'ggbal', 'gges', 'ggesx', 'ggev', 'ggevx', 'ggglm', 'gghrd',
    'gglse', 'ggqrf', 'ggrqf', 'ggsvd', 'ggsvp', 'gtcon', 'gtrfs', 'gtsv',
    'gtsvx', 'gttrf', 'gttrs', 'hgeqz', 'hsein', 'hseqr', 'opgtr', 'opmtr',
    'orgbr', 'orghr', 'orglq', 'orgql', 'orgqr', 'orgrq', 'orgtr', 'ormbr',
    'ormhr', 'ormlq', 'ormql', 'ormqr', 'ormrq', 'ormrz', 'ormtr', 'pbcon',
    'pbequ', 'pbrfs', 'pbstf', 'pbsv', 'pbsvx', 'pbtrf', 'pbtrs', 'pftrf',
    'pftri', 'pftrs', 'pocon', 'poequ', 'poequb', 'porfs', 'porfsx', 'posv',
    'posvx', 'posvxx', 'potrf', 'potri', 'potrs', 'ppcon', 'ppequ', 'pprfs',
    'ppsv', 'ppsvx', 'pptrf', 'pptri', 'pptrs', 'pstrf', 'ptcon', 'pteqr',
    'ptrfs', 'ptsv', 'ptsvx', 'pttrf', 'pttrs', 'sbev', 'sbevd', 'sbevx',
    'sbgst', 'sbgv', 'sbgvd', 'sbgvx', 'sbtrd', 'sfrk', 'spcon', 'spev',
    'spevd', 'spevx', 'spgst', 'spgv', 'spgvd', 'spgvx', 'sprfs', 'spsv',
    'spsvx', 'sptrd', 'sptrf', 'sptri', 'sptrs', 'stebz', 'stedc', 'stegr',
    'stein', 'stemr', 'steqr', 'sterf', 'stev', 'stevd', 'stevr', 'stevx',
    'sycon', 'syequb', 'syev', 'syevd', 'syevr', 'syevx', 'sygst', 'sygv',
    'sygvd', 'sygvx', 'syrfs', 'syrfsx', 'sysv', 'sysvx', 'sysvxx', 'sytrd',
    'sytrf', 'sytri', 'sytrs', 'tbcon', 'tbrfs', 'tbtrs', 'tfsm', 'tftri',
    'tfttp', 'tfttr', 'tgevc', 'tgexc', 'tgsen', 'tgsja', 'tgsna', 'tgsyl',
    'tpcon', 'tprfs', 'tptri', 'tptrs', 'tpttf', 'tpttr', 'trcon', 'trevc',
    'trexc', 'trrfs', 'trsen', 'trsna', 'trsyl', 'trtri', 'trtrs', 'trttf',
    'trttp', 'tzrzf'
]

complex = [
    'bdsqr', 'gbbrd', 'gbcon', 'gbequ', 'gbequb', 'gbrfs', 'gbrfsx', 'gbsv',
    'gbsvx', 'gbsvxx', 'gbtrf', 'gbtrs', 'gebak', 'gebal', 'gebrd', 'gecon',
    'geequ', 'geequb', 'gees', 'geesx', 'geev', 'geevx', 'gehrd', 'gelqf',
    'gels', 'gelsd', 'gelss', 'gelsy', 'geqlf', 'geqp3', 'geqpf', 'geqrf',
    'geqrfp', 'gerfs', 'gerfsx', 'gerqf', 'gesdd', 'gesv', 'gesvd', 'gesvx',
    'gesvxx', 'getrf', 'getri', 'getrs', 'ggbak', 'ggbal', 'gges', 'ggesx',
    'ggev', 'ggevx', 'ggglm', 'gghrd', 'gglse', 'ggqrf', 'ggrqf', 'ggsvd',
    'ggsvp', 'gtcon', 'gtrfs', 'gtsv', 'gtsvx', 'gttrf', 'gttrs', 'hbev',
    'hbevd', 'hbevx', 'hbgst', 'hbgv', 'hbgvd', 'hbgvx', 'hbtrd', 'hecon',
    'heequb', 'heev', 'heevd', 'heevr', 'heevx', 'hegst', 'hegv', 'hegvd',
    'hegvx', 'herfs', 'herfsx', 'hesv', 'hesvx', 'hesvxx', 'hetrd', 'hetrf',
    'hetri', 'hetrs', 'hfrk', 'hgeqz', 'hpcon', 'hpev', 'hpevd', 'hpevx',
    'hpgst', 'hpgv', 'hpgvd', 'hpgvx', 'hprfs', 'hpsv', 'hpsvx', 'hptrd',
    'hptrf', 'hptri', 'hptrs', 'hsein', 'hseqr', 'pbcon', 'pbequ', 'pbrfs',
    'pbstf', 'pbsv', 'pbsvx', 'pbtrf', 'pbtrs', 'pftrf', 'pftri', 'pftrs',
    'pocon', 'poequ', 'poequb', 'porfs', 'porfsx', 'posv', 'posvx', 'posvxx',
    'potrf', 'potri', 'potrs', 'ppcon', 'ppequ', 'pprfs', 'ppsv', 'ppsvx',
    'pptrf', 'pptri', 'pptrs', 'pstrf', 'ptcon', 'pteqr', 'ptrfs', 'ptsv',
    'ptsvx', 'pttrf', 'pttrs', 'spcon', 'sprfs', 'spsv', 'spsvx', 'sptrf',
    'sptri', 'sptrs', 'stedc', 'stegr', 'stein', 'stemr', 'steqr', 'sycon',
    'syequb', 'syrfs', 'syrfsx', 'sysv', 'sysvx', 'sysvxx', 'sytrf', 'sytri',
    'sytrs', 'tbcon', 'tbrfs', 'tbtrs', 'tfsm', 'tftri', 'tfttp', 'tfttr',
    'tgevc', 'tgexc', 'tgsen', 'tgsja', 'tgsna', 'tgsyl', 'tpcon', 'tprfs',
    'tptri', 'tptrs', 'tpttf', 'tpttr', 'trcon', 'trevc', 'trexc', 'trrfs',
    'trsen', 'trsna', 'trsyl', 'trtri', 'trtrs', 'trttf', 'trttp', 'tzrzf',
    'ungbr', 'unghr', 'unglq', 'ungql', 'ungqr', 'ungrq', 'ungtr', 'unmbr',
    'unmhr', 'unmlq', 'unmql', 'unmqr', 'unmrq', 'unmrz', 'unmtr', 'upgtr',
    'upmtr'
]

names = pd.DataFrame(
            ["LAPACKE_" + i 
                for i in 
                    ["s" + i for i in real] + ["d" + i for i in real] + ["c" + i for i in complex] + ["z" + i for i in complex]
            ],
            columns=["fct_name"]
)

# %%
import re
import pandas as pd

### Generated using CHATGPT

def extract_function_info(file_path):
    function_info = []
    pattern =  r"(\w+\s+)(\w+)\s*\((.*?)\);"

    with open(file_path, 'r') as file:
        content = file.read()

        matches = re.findall(pattern, content, re.DOTALL)
        for match in matches:
            return_type = match[0].strip()

            if not "lapack_int" in return_type:
                continue

            function_name = match[1]
            if function_name[-2::] == "sx":
                continue
            
            arguments = match[2].split(',')

            for i, arg in enumerate(arguments):
                arg = arg.strip()
                arg_parts = arg.rsplit(' ', 1)
                arg_type = arg_parts[0].strip()
                arg_name = arg_parts[1].strip()
                
                function_info.append({
                    "fct_name": function_name,
                    "return_type": return_type,
                    "e_name": function_name.split("_")[1],
                    "arg_pos": i,
                    "arg_type": arg_type,
                    "arg_name": arg_name
                })

    return pd.DataFrame(function_info)

# Usage example
db = extract_function_info('lapacke.h')
db = db[db["fct_name"].isin(names["fct_name"])]
db.to_csv("lapacke.csv")

# %% [markdown]
# ##### Comparing functions invented/expected

# %%
print("Missing:")
print(names[~names["fct_name"].isin(db["fct_name"])])

print("Added")
print(db[~db["fct_name"].isin(names["fct_name"])])
# Out:
# Missing:
#             fct_name
# 8    LAPACKE_sgbrfsx
# 21    LAPACKE_sgeesx
# 37   LAPACKE_sgerfsx
# 51    LAPACKE_sggesx
# 102  LAPACKE_sporfsx
# 171  LAPACKE_ssyrfsx
# 218  LAPACKE_dgbrfsx
# 231   LAPACKE_dgeesx
# 247  LAPACKE_dgerfsx
# 261   LAPACKE_dggesx
# 312  LAPACKE_dporfsx
# 381  LAPACKE_dsyrfsx
# 426  LAPACKE_cgbrfsx
# 439   LAPACKE_cgeesx
# 454  LAPACKE_cgerfsx
# 467   LAPACKE_cggesx
# 502  LAPACKE_cherfsx
# 544  LAPACKE_cporfsx
# 582  LAPACKE_csyrfsx
# 643  LAPACKE_zgbrfsx
# 656   LAPACKE_zgeesx
# 671  LAPACKE_zgerfsx
# 684   LAPACKE_zggesx
# 719  LAPACKE_zherfsx
# 761  LAPACKE_zporfsx
# 799  LAPACKE_zsyrfsx
# Added
# Empty DataFrame
# Columns: [fct_name, return_type, e_name, arg_pos, arg_type, arg_name]
# Index: []

# %% [markdown]
# ### Obtained data types

# %%
data_types = db["arg_type"].unique()
print(data_types)
# Out:
# ['int' 'char' 'lapack_int' 'float*' 'lapack_int*' 'double*'
#  'lapack_complex_float*' 'lapack_complex_double*' 'const float*'
#  'const double*' 'const lapack_int*' 'float' 'double'
#  'const lapack_complex_float*' 'const lapack_complex_double*' 'char*'
#  'LAPACK_S_SELECT2' 'LAPACK_D_SELECT2' 'LAPACK_C_SELECT1'
#  'LAPACK_Z_SELECT1' 'LAPACK_S_SELECT3' 'LAPACK_D_SELECT3'
#  'LAPACK_C_SELECT2' 'LAPACK_Z_SELECT2' 'lapack_logical*'
#  'const lapack_logical*' 'lapack_complex_float' 'lapack_complex_double'
#  'lapack_logical']

# %%
for dt in data_types:
    print(dt)
    dt_df = db[db["arg_type"]==dt]
    data = {
        "names": dt_df["arg_name"].unique(),
        "pos": dt_df["arg_pos"].unique(),
        "ocs": dt_df.size
    }
    print(data)
# Out:
# int
# {'names': array(['matrix_layout'], dtype=object), 'pos': array([0]), 'ocs': 4992}
# char
# {'names': array(['uplo', 'compq', 'job', 'vect', 'norm', 'trans', 'equed', 'fact',
#        'side', 'jobvs', 'sort', 'sense', 'jobvl', 'jobvr', 'balanc',
#        'joba', 'jobu', 'jobv', 'jobr', 'jobt', 'jobp', 'jobz', 'jobvt',
#        'jobvsl', 'jobvsr', 'compz', 'jobq', 'range', 'transr', 'eigsrc',
#        'initv', 'order', 'diag', 'howmny', 'trana', 'tranb'], dtype=object), 'pos': array([1, 2, 0, 4, 3, 5, 6]), 'ocs': 7404}
# lapack_int
# {'names': array(['n', 'ldu', 'ldvt', 'ncvt', 'nru', 'ncc', 'ldc', 'm', 'kl', 'ku',
#        'ldab', 'ldq', 'ldpt', 'nrhs', 'ldafb', 'ldb', 'ldx', 'n_err_bnds',
#        'nparams', 'ilo', 'ihi', 'ldv', 'lda', 'ldvs', 'ldvl', 'ldvr',
#        'ldaf', 'mv', 'ldvsl', 'ldvsr', 'p', 'ldz', 'kd', 'il', 'iu', 'ka',
#        'kb', 'ldbb', 'itype', 'k', 'ldh', 'ldt', 'mm', 'l', 'nzc', 'lds',
# ...

# %%
print(db[db["arg_type"]=="char"]["arg_name"].unique())
#print(db[(db["arg_type"] == "char")])
# Out:
# ['uplo' 'compq' 'job' 'vect' 'norm' 'trans' 'equed' 'fact' 'side' 'jobvs'
#  'sort' 'sense' 'jobvl' 'jobvr' 'balanc' 'joba' 'jobu' 'jobv' 'jobr'
#  'jobt' 'jobp' 'jobz' 'jobvt' 'jobvsl' 'jobvsr' 'compz' 'jobq' 'range'
#  'transr' 'eigsrc' 'initv' 'order' 'diag' 'howmny' 'trana' 'tranb']

# %%
print(db[db["fct_name"] == "LAPACKE_sdisna"])
# Out:
#            fct_name return_type  e_name  arg_pos      arg_type arg_name
# 112  LAPACKE_sdisna  lapack_int  sdisna        0          char      job
# 113  LAPACKE_sdisna  lapack_int  sdisna        1    lapack_int        m
# 114  LAPACKE_sdisna  lapack_int  sdisna        2    lapack_int        n
# 115  LAPACKE_sdisna  lapack_int  sdisna        3  const float*        d
# 116  LAPACKE_sdisna  lapack_int  sdisna        4        float*      sep
